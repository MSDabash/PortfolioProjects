# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

# Display all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Normalizes the data and place it in a dataframe

pd.json_normalize(data['data']).head(10)
# Out:
#      id         name symbol         slug  num_market_pairs  \
# 0     1      Bitcoin    BTC      bitcoin              9620
# 1  1027     Ethereum    ETH     ethereum              5823
# 2   825       Tether   USDT       tether             36141
# 3  3408     USD Coin   USDC     usd-coin              4868
# 4  1839          BNB    BNB          bnb              1006
# 5  4687  Binance USD   BUSD  binance-usd              4055
# 6    52          XRP    XRP          xrp               765
# 7  2010      Cardano    ADA      cardano               518
# 8  5426       Solana    SOL       solana               349
# 9    74     Dogecoin   DOGE     dogecoin               506
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2015-02-25T00:00:00.000Z
# 3  2018-10-08T00:00:00.000Z
# 4  2017-07-25T00:00:00.000Z
# 5  2019-09-20T00:00:00.000Z
# 6  2013-08-04T00:00:00.000Z
# 7  2017-10-01T00:00:00.000Z
# 8  2020-04-10T00:00:00.000Z
# 9  2013-12-15T00:00:00.000Z
#
#                                                 tags    max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1  [mineable, pow, smart-contracts, ethereum-ecos...           NaN
# 2  [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3  [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 4  [marketplace, centralized-exchange, payments, ...  1.651168e+08
# 5  [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 6  [medium-of-exchange, enterprise-solutions, bin...  1.000000e+11
# 7  [mineable, dpos, pos, platform, research, smar...  4.500000e+10
# 8  [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 9  [mineable, pow, scrypt, medium-of-exchange, me...           NaN
#
#    circulating_supply  total_supply  platform  cmc_rank  \
# 0        1.909402e+07  1.909402e+07       NaN         1
# 1        1.215529e+08  1.215529e+08       NaN         2
# 2        6.587632e+10  6.816698e+10       NaN         3
# 3        5.525638e+10  5.525638e+10       NaN         4
# 4        1.632770e+08  1.632770e+08       NaN         5
# 5        1.754722e+10  1.754722e+10       NaN         6
# 6        4.834310e+10  9.998954e+10       NaN         7
# 7        3.393405e+10  3.427770e+10       NaN         8
# 8        3.455755e+08  5.116169e+08       NaN         9
# 9        1.326708e+11  1.326708e+11       NaN        10
#
#    self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                               NaN                       NaN        NaN
# 1                               NaN                       NaN        NaN
# 2                               NaN                       NaN        NaN
# 3                               NaN                       NaN        NaN
# 4                               NaN                       NaN        NaN
# 5                               NaN                       NaN        NaN
# 6                               NaN                       NaN        NaN
# 7                               NaN                       NaN        NaN
# 8                               NaN                       NaN        NaN
# 9                               NaN                       NaN        NaN
#
#                last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0  2022-07-15T06:18:00.000Z     20631.939846          3.659036e+10
# 1  2022-07-15T06:17:00.000Z      1202.872573          1.783902e+10
# 2  2022-07-15T06:17:00.000Z         0.999560          5.170375e+10
# 3  2022-07-15T06:17:00.000Z         1.000019          5.561503e+09
# 4  2022-07-15T06:17:00.000Z       237.675878          1.700850e+09
# 5  2022-07-15T06:17:00.000Z         1.001567          6.038872e+09
# 6  2022-07-15T06:18:00.000Z         0.341168          8.250901e+09
# 7  2022-07-15T06:17:00.000Z         0.442471          8.863361e+08
# 8  2022-07-15T06:17:00.000Z        37.071178          1.313247e+09
# 9  2022-07-15T06:17:00.000Z         0.062517          3.611757e+08
#
#    quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       4.3441                     0.445668
# 1                      -2.2448                     0.772206
# 2                      -5.2291                     0.002855
# 3                      -2.1897                    -0.004772
# 4                      14.7742                     0.345551
# 5                      -4.5046                     0.036300
# 6                     554.5120                    -0.410663
# 7                     -10.6482                     0.282859
# 8                      -5.8005                    -0.001378
# 9                     -17.2612                     0.505966
#
#    quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      2.660755                    -5.494358
# 1                      8.823080                    -3.405565
# 2                      0.012288                     0.008113
# 3                     -0.002161                     0.001416
# 4                      2.983359                    -1.626779
# 5                      0.186810                     0.009569
# 6                      5.980997                    -3.009937
# 7                      2.810398                    -7.369145
# 8                      7.639490                    -2.241700
# 9                      2.858250                   -11.669081
#
#    quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                     -2.553479                    -31.091853
# 1                      7.380612                    -41.169596
# 2                      0.090955                      0.066782
# 3                     -0.012002                      0.007668
# 4                     12.522643                    -19.982051
# 5                      0.071550                     -0.080364
# 6                     12.337631                    -19.147571
# 7                     -4.021590                    -21.774596
# 8                     32.209852                    -32.320140
# 9                     19.860618                    -29.611387
#
#    quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                    -48.993490          3.939466e+11
# 1                    -60.430015          1.462126e+11
# 2                     -0.064472          6.584734e+10
# 3                      0.023265          5.525743e+10
# 4                    -42.786677          3.880700e+10
# 5                      0.300838          1.757472e+10
# 6                    -56.559837          1.649314e+10
# 7                    -53.787195          1.501484e+10
# 8                    -63.504633          1.281089e+10
# 9                    -57.182889          8.294209e+09
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         42.4542                        4.332707e+11
# 1                         15.7568                        1.462126e+11
# 2                          7.0961                        6.813700e+10
# 3                          5.9549                        5.525743e+10
# 4                          4.1805                        3.924427e+10
# 5                          1.8927                        1.757472e+10
# 6                          1.7774                        3.411684e+10
# 7                          1.6181                        1.991121e+10
# 8                          1.3797                        1.896624e+10
# 9                          0.8932                        8.294209e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0            NaN  2022-07-15T06:18:00.000Z          NaN           NaN
# 1            NaN  2022-07-15T06:17:00.000Z          NaN           NaN
# 2            NaN  2022-07-15T06:17:00.000Z       1027.0      Ethereum
# 3            NaN  2022-07-15T06:17:00.000Z       1027.0      Ethereum
# 4            NaN  2022-07-15T06:17:00.000Z          NaN           NaN
# 5            NaN  2022-07-15T06:17:00.000Z       1839.0           BNB
# 6            NaN  2022-07-15T06:18:00.000Z          NaN           NaN
# 7            NaN  2022-07-15T06:17:00.000Z          NaN           NaN
# 8            NaN  2022-07-15T06:17:00.000Z          NaN           NaN
# 9            NaN  2022-07-15T06:17:00.000Z          NaN           NaN
#
#   platform.symbol platform.slug                      platform.token_address
# 0             NaN           NaN                                         NaN
# 1             NaN           NaN                                         NaN
# 2             ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4             NaN           NaN                                         NaN
# 5             BNB           bnb                                    BUSD-BD1
# 6             NaN           NaN                                         NaN
# 7             NaN           NaN                                         NaN
# 8             NaN           NaN                                         NaN
# 9             NaN           NaN                                         NaN
